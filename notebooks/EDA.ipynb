# %%
import pandas as pd
import streamlit as st
import plotly.express as px

print("Los paquetes están instalados correctamente.")
# Out:
# Los paquetes están instalados correctamente.

# %%
# Leer los datos
car_data = pd.read_csv('vehicles_us.csv')

# Crear una nueva columna que agrupa el odómetro en categorías
car_data["odometer_group"] = pd.cut(car_data["odometer"], bins=5, labels=["Bajo", "Medio-Bajo", "Medio", "Medio-Alto", "Alto"])

# Crear un histograma con colores según los rangos de odómetro
fig = px.histogram(
    car_data, 
    x="odometer", 
    color="odometer_group",  # Colorea según el grupo de kilometraje
    title="Distribución del Odómetro en los Vehículos",
    labels={"odometer": "Kilometraje", "odometer_group": "Grupo de Kilometraje"},
    color_discrete_sequence=px.colors.qualitative.Set2  # Paleta de colores atractiva
)

# Mostrar el gráfico
fig.show()

# %%
# Leer los datos
car_data = pd.read_csv('vehicles_us.csv')

# Crear un gráfico de dispersión con colores según la condición del vehículo
fig = px.scatter(
    car_data, 
    x="odometer", 
    y="price", 
    color="condition",  # Colorea los puntos según la condición del auto
    title="Relación entre Kilometraje y Precio de Vehículos",
    labels={"odometer": "Kilometraje", "price": "Precio"},
    color_discrete_sequence=px.colors.qualitative.Set1  # Paleta de colores llamativa
)

# Mostrar el gráfico
fig.show()
